# %% [markdown]
# ## Import useful libraries

# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# I loaded the model which I saved as shown in the earlier file where the model was trained

# %%
model=tf.keras.models.load_model(r"C:\Soup\soup model")
model

# %% [markdown]
# I used softmax for the output layer, so I multiplied the values by hundred so we can easily visualise the accuracy

# %%
test_dir=r"C:\Soup\test"
image_gen=ImageDataGenerator(rescale=1./255)
test_gen=image_gen.flow_from_directory(directory=test_dir, target_size=(224,224), shuffle=False)
predict=model.predict(test_gen)
predict=predict*100
names=['afang','egusi','ewedu','oha','okro']
df=pd.DataFrame(predict,columns=[names])
print(df)
# Out:
# Found 30 images belonging to 1 classes.
#         afang      egusi      ewedu        oha       okro
# 0    1.635283   0.255962   6.523319   1.969903  89.615532
# 1    0.076221   0.140277  99.261681   0.321084   0.200729
# 2   92.147560   1.681011   2.779307   2.769184   0.622936
# 3    0.038960   0.169901  97.955338   0.197139   1.638672
# 4    0.029203   0.000287  99.635399   0.243362   0.091756
# 5   24.849152   3.998960  20.773512  50.141941   0.236427
# 6    1.236552   0.021485  97.529503   0.035705   1.176755
# 7    0.425372   0.008992  98.409515   0.092957   1.063161
# 8    0.405693   0.000112  99.587700   0.005830   0.000662
# 9    0.110158   0.023697  99.071487   0.673460   0.121191
# 10   0.067346   0.078252  94.143929   0.034849   5.675637
# 11   7.081971   0.029605  55.379711  34.226803   3.281905
# 12   0.064885   0.000549  99.572029   0.235316   0.127207
# 13   1.564070   0.058943  19.526318  74.556229   4.294443
# ...

# %% [markdown]
# Visualised the images and the predictions along side

# %%
plt.imshow(test_gen[0][0][0])
print(df.iloc[0])
# Out:
# afang     1.635283
# egusi     0.255962
# ewedu     6.523319
# oha       1.969903
# okro     89.615532
# Name: 0, dtype: float32

# %%
plt.imshow(test_gen[0][0][1])
print(df.iloc[1])
# Out:
# afang     0.076221
# egusi     0.140277
# ewedu    99.261681
# oha       0.321084
# okro      0.200729
# Name: 1, dtype: float32

# %%
plt.imshow(test_gen[0][0][2])
print(df.iloc[2])
# Out:
# afang    92.147560
# egusi     1.681011
# ewedu     2.779307
# oha       2.769184
# okro      0.622936
# Name: 2, dtype: float32

# %%
plt.imshow(test_gen[0][0][3])
print(df.iloc[3])
# Out:
# afang     0.038960
# egusi     0.169901
# ewedu    97.955338
# oha       0.197139
# okro      1.638672
# Name: 3, dtype: float32

# %%
plt.imshow(test_gen[0][0][4])
print(df.iloc[4])
# Out:
# afang     0.029203
# egusi     0.000287
# ewedu    99.635399
# oha       0.243362
# okro      0.091756
# Name: 4, dtype: float32

# %%
plt.imshow(test_gen[0][0][5])
print(df.iloc[5])
# Out:
# afang    24.849152
# egusi     3.998960
# ewedu    20.773512
# oha      50.141941
# okro      0.236427
# Name: 5, dtype: float32

# %%
plt.imshow(test_gen[0][0][6])
print(df.iloc[6])
# Out:
# afang     1.236552
# egusi     0.021485
# ewedu    97.529503
# oha       0.035705
# okro      1.176755
# Name: 6, dtype: float32

# %%
plt.imshow(test_gen[0][0][7])
print(df.iloc[7])
# Out:
# afang     0.425372
# egusi     0.008992
# ewedu    98.409515
# oha       0.092957
# okro      1.063161
# Name: 7, dtype: float32

# %%
plt.imshow(test_gen[0][0][8])
print(df.iloc[8])
# Out:
# afang     0.405693
# egusi     0.000112
# ewedu    99.587700
# oha       0.005830
# okro      0.000662
# Name: 8, dtype: float32

# %%
plt.imshow(test_gen[0][0][9])
print(df.iloc[9])
# Out:
# afang     0.110158
# egusi     0.023697
# ewedu    99.071487
# oha       0.673460
# okro      0.121191
# Name: 9, dtype: float32

# %%
plt.imshow(test_gen[0][0][10])
print(df.iloc[10])
# Out:
# afang     0.067346
# egusi     0.078252
# ewedu    94.143929
# oha       0.034849
# okro      5.675637
# Name: 10, dtype: float32

# %%
plt.imshow(test_gen[0][0][11])
print(df.iloc[11])
# Out:
# afang     7.081971
# egusi     0.029605
# ewedu    55.379711
# oha      34.226803
# okro      3.281905
# Name: 11, dtype: float32

# %%
plt.imshow(test_gen[0][0][12])
print(df.iloc[12])
# Out:
# afang     0.064885
# egusi     0.000549
# ewedu    99.572029
# oha       0.235316
# okro      0.127207
# Name: 12, dtype: float32

# %%
plt.imshow(test_gen[0][0][13])
print(df.iloc[13])
# Out:
# afang     1.564070
# egusi     0.058943
# ewedu    19.526318
# oha      74.556229
# okro      4.294443
# Name: 13, dtype: float32

# %%
plt.imshow(test_gen[0][0][14])
print(df.iloc[14])
# Out:
# afang     1.916053
# egusi     0.561463
# ewedu    96.857872
# oha       0.638236
# okro      0.026378
# Name: 14, dtype: float32

# %%
plt.imshow(test_gen[0][0][15])
print(df.iloc[15])
# Out:
# afang     0.489769
# egusi     0.174703
# ewedu    98.339691
# oha       0.316417
# okro      0.679417
# Name: 15, dtype: float32

# %%
plt.imshow(test_gen[0][0][16])
print(df.iloc[16])
# Out:
# afang     3.976304
# egusi    83.925369
# ewedu     0.032810
# oha      12.051370
# okro      0.014160
# Name: 16, dtype: float32

# %%
plt.imshow(test_gen[0][0][17])
print(df.iloc[17])
# Out:
# afang     1.271044
# egusi    90.931908
# ewedu     0.178118
# oha       4.138164
# okro      3.480757
# Name: 17, dtype: float32

# %%
plt.imshow(test_gen[0][0][18])
print(df.iloc[18])
# Out:
# afang     0.026929
# egusi    98.412712
# ewedu     0.219402
# oha       1.188308
# okro      0.152652
# Name: 18, dtype: float32

# %%
plt.imshow(test_gen[0][0][19])
print(df.iloc[19])
# Out:
# afang     0.005699
# egusi    99.798264
# ewedu     0.000836
# oha       0.178412
# okro      0.016785
# Name: 19, dtype: float32

# %%
plt.imshow(test_gen[0][0][20])
print(df.iloc[20])
# Out:
# afang     1.352962
# egusi    79.120293
# ewedu     1.382896
# oha       4.338298
# okro     13.805552
# Name: 20, dtype: float32

# %%
plt.imshow(test_gen[0][0][21])
print(df.iloc[21])
# Out:
# afang     7.007641
# egusi    87.536491
# ewedu     2.918999
# oha       1.867030
# okro      0.669844
# Name: 21, dtype: float32

# %%
plt.imshow(test_gen[0][0][22])
print(df.iloc[22])
# Out:
# afang     3.767293
# egusi    93.991936
# ewedu     0.532282
# oha       1.662325
# okro      0.046177
# Name: 22, dtype: float32

# %%
plt.imshow(test_gen[0][0][23])
print(df.iloc[23])
# Out:
# afang    29.820364
# egusi    57.350624
# ewedu     1.550624
# oha      10.267288
# okro      1.011099
# Name: 23, dtype: float32

# %%
plt.imshow(test_gen[0][0][24])
print(df.iloc[24])
# Out:
# afang     0.674066
# egusi    74.378265
# ewedu    12.845418
# oha       4.148276
# okro      7.953984
# Name: 24, dtype: float32

# %%
plt.imshow(test_gen[0][0][25])
print(df.iloc[25])
# Out:
# afang     4.157506
# egusi    90.956192
# ewedu     0.133035
# oha       2.541562
# okro      2.211704
# Name: 25, dtype: float32

# %%
plt.imshow(test_gen[0][0][26])
print(df.iloc[26])
# Out:
# afang     0.200898
# egusi     3.178397
# ewedu    22.988548
# oha      31.788641
# okro     41.843517
# Name: 26, dtype: float32

# %%
plt.imshow(test_gen[0][0][27])
print(df.iloc[27])
# Out:
# afang     4.950512
# egusi    90.485634
# ewedu     2.455873
# oha       0.271742
# okro      1.836249
# Name: 27, dtype: float32

# %%
plt.imshow(test_gen[0][0][28])
print(df.iloc[28])
# Out:
# afang     0.291207
# egusi    99.390594
# ewedu     0.105055
# oha       0.175405
# okro      0.037737
# Name: 28, dtype: float32

# %%
plt.imshow(test_gen[0][0][29])
print(df.iloc[29])
# Out:
# afang     1.669639
# egusi    81.975845
# ewedu     9.375912
# oha       0.059561
# okro      6.919039
# Name: 29, dtype: float32
